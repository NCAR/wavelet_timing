# %% [markdown]
# # Wavelet Timing
# Codes to reproduce
# "A Wavelet-Based Approach to Streamflow Event Identification and Modeled Timing Error Evaluation"
# E. Towler & J. McCreight

# %% [markdown]
# ## Preliminaries

# %%
options(warn=1)
devtools::install_github("https://github.com/NCAR/rwrfhydro", dependencies="")
library(rwrfhydro)
# Out:
# Skipping install of 'rwrfhydro' from a github remote, the SHA1 (7bffeb6d) has not changed since last install.
#   Use `force = TRUE` to force installation
# To check rwrfhydro updates run: CheckForUpdates()
#
# Attaching package: ‘rwrfhydro’
#
# The following object is masked from ‘package:base’:
#
#     multiplot

# %% [markdown]
# ## Figure 1

# %%
source('figure_01.R')  # Suppress output manually

# %%
plot(figure)
# Out:
# plot without title

# %% [markdown]
# ## Figure 2

# %%
source('figure_02.R')  # Suppress output manually

# %%
plot(figure)
# Out:
# plot without title

# %% [markdown]
# ## Figure 3

# %%
source('figure_03.R')  # Suppress output manually

# %%
plot(figure)
# Out:
# plot without title

# %% [markdown]
# ## Figure 4

# %%
source('figure_04.R')  # Suppress output manually

# %%
plot(figure)
# Out:
# plot without title

# %% [markdown]
# ## Figure 5

# %%
source('figure_05.R')  # Suppress output manually

# %%
plot(figure)
# Out:
# `stat_bin()` using `bins = 30`. Pick better value with `binwidth`.
# plot without title

# %% [markdown]
# ## Figure 6

# %%
source('figure_06.R')  # Suppress output manually

# %%
plot(figure)
# Out:
# plot without title

# %% [markdown]
# ## Figure 7

# %%
source('figure_07.R')  # Suppress output manually

# %%
plot(figure)
# Out:
# plot without title

# %% [markdown]
# ## Figure 8

# %%
source('figure_08.R')  # Suppress output manually

# %%
plot(figure)
# Out:
# plot without title

# %% [markdown]
# ## Figure 9

# %%
source('figure_09.R')  # Suppress output manually

# %%
plot(figure)
# Out:
# `stat_bin()` using `bins = 30`. Pick better value with `binwidth`.
# plot without title

# %% [markdown]
# ## Figure 10

# %%
source('figure_10.R')  # Suppress output manually

# %%
plot(figure)
# Out:
# `stat_bin()` using `bins = 30`. Pick better value with `binwidth`.
# plot without title

# %% [markdown]
# ## Figure 11

# %%
source('figure_11.R')  # Suppress output manually

# %%
plot(figure$ggplot)
# Out:
# plot without title

# %% [markdown]
# ## Figure 12

# %%
source('figure_12.R')  # Suppress output manually

# %%
plot(figure$ggplot)
# Out:
# plot without title

# %% [markdown]
# ## Supplemental Figure 2

# %%
source('supp_figure_02.R')  # Suppress output manually

# %%
plot(figure)
# Out:
# plot without title

# %% [markdown]
# ## Supplemental Figure 3

# %%
source("supp_figure_03.R")  # Suppress output manually

# %%
plot(figure$ggplot)
# Out:
# plot without title

# %% [markdown]
# ## Supplemental Figure 4

# %%
source("supp_figure_04.R")  # Suppress output manually

# %%
plot(figure)
# Out:
# plot without title

# %% [markdown]
# ## Supplemental Figure 5

# %%
source("supp_figure_05.R")  # Suppress output manually

# %%
plot(figure)
# Out:
# plot without title

# %% [markdown]
# ## Supplemental Figure 6

# %%
source("supp_figure_06.R")  # Suppress output manually

# %%
plot(figure)
# Out:
# plot without title
